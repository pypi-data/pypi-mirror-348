# %% [markdown]
# ## MyShareData

# %%
import akshare as ak
from mysharelib import MyShareData

yf_data = MyShareData.from_source('yahoo')
ak_data = MyShareData.from_source('akshare')

# %%
from mysharelib.ak_data import get_stock_spot
symbols = ['00700']
prices = ak_data.get_stock_prices(symbols)
#price = get_stock_spot('02202')
#print(f"{price}\n{price['current_price']}")
print(prices)
# Out:
# {'00700': 516.0}

# %%
symbol = '0700'
data = ak_data.get_stock_history(symbol, '20230101', '20230110')
data
# Out:
# [{'symbol': '00700',
#   'market': 'HK',
#   'date': datetime.datetime(2023, 1, 3, 0, 0),
#   'open': 334.0,
#   'close': 345.2,
#   'high': 345.8,
#   'low': 328.8,
#   'volume': 29957513.0,
#   'source': 'akshare'},
#  {'symbol': '00700',
#   'market': 'HK',
#   'date': datetime.datetime(2023, 1, 4, 0, 0),
#   'open': 350.0,
#   'close': 361.0,
#   'high': 361.0,
#   'low': 349.0,
#   'volume': 37429922.0,
#   'source': 'akshare'},
#  {'symbol': '00700',
#   'market': 'HK',
#   'date': datetime.datetime(2023, 1, 5, 0, 0),
#   'open': 358.0,
#   'close': 347.8,
#   'high': 362.2,
#   'low': 343.6,
#   'volume': 40803927.0,
#   'source': 'akshare'},
#  {'symbol': '00700',
#   'market': 'HK',
#   'date': datetime.datetime(2023, 1, 6, 0, 0),
#   'open': 353.6,
#   'close': 349.4,
#   'high': 359.4,
#   'low': 346.8,
#   'volume': 27092487.0,
#   'source': 'akshare'},
#  {'symbol': '00700',
#   'market': 'HK',
#   'date': datetime.datetime(2023, 1, 9, 0, 0),
#   'open': 355.0,
#   'close': 362.0,
#   'high': 362.4,
#   'low': 351.6,
#   'volume': 28323733.0,
#   'source': 'akshare'},
#  {'symbol': '00700',
#   'market': 'HK',
#   'date': datetime.datetime(2023, 1, 10, 0, 0),
#   'open': 365.0,
#   'close': 362.4,
#   'high': 365.8,
#   'low': 357.0,
#   'volume': 19854116.0,
#   'source': 'akshare'}]

# %%
df_stock = ak.stock_zh_a_hist(
    symbol="600325",
    start_date="20250401",
    end_date="20250404",
    period="daily",
    adjust=""
)    
df_stock
# Out:
#            日期    股票代码    开盘    收盘    最高    最低     成交量          成交额    振幅  \
# 0  2025-04-01  600325  5.33  5.37  5.38  5.32  168477   90254138.0  1.13
# 1  2025-04-02  600325  5.36  5.33  5.38  5.32  177776   95088458.0  1.12
# 2  2025-04-03  600325  5.30  5.36  5.43  5.29  263771  141826154.0  2.63
#
#     涨跌幅   涨跌额   换手率
# 0  0.75  0.04  0.66
# 1 -0.74 -0.04  0.69
# 2  0.56  0.03  1.03

# %%
stock_hk_hist_df = ak.stock_hk_hist(symbol="01027", period="daily", start_date="20250401", end_date="20250404", adjust="")
print(stock_hk_hist_df)
# Out:
#            日期    开盘    收盘    最高    最低     成交量       成交额     振幅   涨跌幅   涨跌额  \
# 0  2025-04-01  0.75  0.88  0.88  0.75  110125   86802.0  14.29 -3.30 -0.03
# 1  2025-04-02  0.95  0.96  1.06  0.95  142500  144675.0  12.50  9.09  0.08
#
#     换手率
# 0  0.03
# 1  0.03

# %%
symbols = ['0144.HK', '0386.HK', '0939.HK', '0998.HK', '1288.HK', '1339.HK', '1398.HK', '2800.HK', '2880.HK', '3988.HK', '6823.HK']
prices = ak_data.get_stock_prices(symbols)
prices
# Out:
# {'0144': 12.9,
#  '0386': 3.97,
#  '0939': 6.58,
#  '0998': 6.15,
#  '1288': 4.75,
#  '1339': 4.73,
#  '1398': 5.43,
#  '2800': 22.96,
#  '2880': 0.67,
#  '3988': 4.48,
#  '6823': 11.36}

# %%
result = ak_data.get_stock_history('0205', '20250421', '20250425')
result
# Out:
# [{'symbol': '0205',
#   'market': 'HK',
#   'date': datetime.datetime(2025, 4, 22, 0, 0),
#   'open': 0.149,
#   'close': 0.149,
#   'high': 0.149,
#   'low': 0.149,
#   'volume': 10000.0,
#   'source': 'akshare'},
#  {'symbol': '0205',
#   'market': 'HK',
#   'date': datetime.datetime(2025, 4, 23, 0, 0),
#   'open': 0.152,
#   'close': 0.149,
#   'high': 0.152,
#   'low': 0.149,
#   'volume': 20000.0,
#   'source': 'akshare'},
#  {'symbol': '0205',
#   'market': 'HK',
#   'date': datetime.datetime(2025, 4, 24, 0, 0),
#   'open': 0.149,
#   'close': 0.149,
#   'high': 0.152,
#   'low': 0.149,
#   'volume': 70000.0,
#   'source': 'akshare'},
#  {'symbol': '0205',
#   'market': 'HK',
#   'date': datetime.datetime(2025, 4, 25, 0, 0),
#   'open': 0.149,
#   'close': 0.149,
#   'high': 0.149,
#   'low': 0.149,
#   'volume': 50.0,
#   'source': 'akshare'}]

# %%
ak_data.get_exchange_rate('USD/CNY')
# Out:
# 7.2365

# %%
from mysharelib.ak_data import get_exchange_rates
rate = get_exchange_rates()
rate
# Out:
# {'USD/CNY': 7.2365,
#  'EUR/CNY': 8.1942,
#  '100JPY/CNY': 5.037,
#  'HKD/CNY': 0.93198,
#  'GBP/CNY': 9.6495,
#  'AUD/CNY': 4.6712,
#  'NZD/CNY': 4.3153,
#  'SGD/CNY': 5.5902,
#  'CHF/CNY': 8.7882,
#  'CAD/CNY': 5.2365,
#  'CNY/MOP': 1.1043,
#  'CNY/MYR': 0.5863,
#  'CNY/RUB': 10.6553,
#  'CNY/ZAR': 2.5192,
#  'CNY/KRW': 192.97,
#  'CNY/AED': 0.50751,
#  'CNY/SAR': 0.51839,
#  'CNY/HUF': 49.323,
#  'CNY/PLN': 0.52156,
#  'CNY/DKK': 0.9105,
#  'CNY/SEK': 1.3318,
#  'CNY/NOK': 1.4283,
#  'CNY/TRY': 5.34202,
#  'CNY/MXN': 2.7055,
#  'CNY/THB': 4.5293}

# %%
import akshare as ak
df = ak.fx_spot_quote()
rates = dict(zip(df['货币对'], df['买报价']))
rates
# Out:
# {'USD/CNY': 7.2264,
#  'EUR/CNY': 8.1971,
#  '100JPY/CNY': 5.0495,
#  'HKD/CNY': 0.932,
#  'GBP/CNY': 9.6455,
#  'AUD/CNY': 4.6877,
#  'NZD/CNY': 4.3362,
#  'SGD/CNY': 5.5956,
#  'CHF/CNY': 8.755,
#  'CAD/CNY': 5.2393,
#  'CNY/MOP': 1.1051,
#  'CNY/MYR': 0.5833,
#  'CNY/RUB': 10.7896,
#  'CNY/ZAR': 2.5225,
#  'CNY/KRW': 193.16,
#  'CNY/AED': 0.50825,
#  'CNY/SAR': 0.51912,
#  'CNY/HUF': 49.373,
#  'CNY/PLN': 0.52179,
#  'CNY/DKK': 0.9103,
#  'CNY/SEK': 1.3273,
#  'CNY/NOK': 1.4246,
#  'CNY/TRY': 5.34643,
#  'CNY/MXN': 2.722,
#  'CNY/THB': 4.5338}

# %%
sgd = ak_data.get_exchange_rate("SGD/CNY")
usd = ak_data.get_exchange_rate("USD/CNY")
aud = ak_data.get_exchange_rate("AUD/CNY")
hkd = ak_data.get_exchange_rate("HKD/CNY")
print(f"SGD/CNY={sgd}, USD/CNY={usd}, AUD/CNY={aud} HKD/CNY={hkd}")
# Out:
# SGD/CNY=5.5954, USD/CNY=7.2266, AUD/CNY=4.6876 HKD/CNY=0.93203

# %% [markdown]
# ## 分红

# %%
import akshare as ak
stock_fhps_detail_em_df = ak.stock_fhps_detail_em(symbol="601601")
print(stock_fhps_detail_em_df)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#            报告期      业绩披露日期  送转股份-送转总比例  送转股份-送股比例  送转股份-转股比例  现金分红-现金分红比例  \
# 0   2007-12-31  2008-04-12         0.0        0.0        0.0          3.0
# 1   2008-12-31  2009-04-11         0.0        0.0        0.0          3.0
# 2   2009-12-31  2010-04-19         0.0        0.0        0.0          3.0
# 3   2010-12-31  2011-03-28         0.0        0.0        0.0          3.5
# 4   2011-12-31  2012-03-26         0.0        0.0        0.0          3.5
# 5   2012-12-31  2013-03-25         NaN        NaN        NaN          3.5
# 6   2013-12-31  2014-03-31         NaN        NaN        NaN          4.0
# 7   2014-12-31  2015-03-30         NaN        NaN        NaN          5.0
# 8   2015-12-31  2016-03-28         NaN        NaN        NaN         10.0
# 9   2016-12-31  2017-03-30         NaN        NaN        NaN          7.0
# 10  2017-12-31  2018-03-30         NaN        NaN        NaN          8.0
# 11  2018-12-31  2019-03-25         NaN        NaN        NaN         10.0
# 12  2019-12-31  2020-03-23         NaN        NaN        NaN         12.0
# 13  2020-12-31  2021-03-29         NaN        NaN        NaN         12.0
# 14  2021-12-31  2022-03-28         NaN        NaN        NaN         10.0
# 15  2022-12-31  2023-03-27         NaN        NaN        NaN         10.2
# 16  2023-12-31  2024-03-29         NaN        NaN        NaN         10.2
# 17  2024-12-31  2025-03-27         NaN        NaN        NaN         10.8
#
#               现金分红-现金分红比例描述  现金分红-股息率  每股收益  每股净资产     每股公积金    每股未分配利润  \
# 0     10派3.00元(含税,扣税后2.70元)  0.014918  1.12   8.16  6.400519   0.642468
# 1     10派3.00元(含税,扣税后2.70元)  0.014837  0.17   6.33  4.700649   0.504545
# 2     10派3.00元(含税,扣税后2.70元)  0.013187  0.95   8.80  6.748438   0.890251
# 3     10派3.50元(含税,扣税后3.15元)  0.016619  1.00   9.34  6.605814   1.537326
# 4     10派3.50元(含税,扣税后3.15元)  0.016174  0.97   8.93  5.584186   2.092209
# 5     10派3.50元(含税,扣税后3.15元)  0.021394  0.59  10.61  7.159126   2.162437
# 6     10派4.00元(含税,扣税后3.60元)  0.022284  1.02  10.92  6.796182   2.791216
# 7     10派5.00元(含税,扣税后4.50元)  0.017206  1.22  12.93  7.365041   2.945707
# 8    10派10.00元(含税,扣税后9.00元)  0.037010  1.96  14.71  7.365041   4.163319
# 9     10派7.00元(含税,扣税后6.30元)  0.019559  1.33  14.54  7.365041   4.278526
# 10    10派8.00元(含税,扣税后7.20元)  0.023966  1.62  15.17  7.350806   5.045465
# 11   10派10.00元(含税,扣税后9.00元)  0.026110  1.99  16.51  7.353233   6.026264
# 12  10派12.00元(含税,扣税后10.80元)  0.040134  3.06  19.69  7.354889   7.790995
# 13  10派12.00元(含税,扣税后10.80元)  0.039907  2.63  22.37  8.293971   8.475364
# 14   10派10.00元(含税,扣税后9.00元)  0.043706  2.79  23.57  8.280873   9.684927
# 15   10派10.20元(含税,扣税后9.18元)  0.037736  2.56  23.75  8.281185  10.936071
# 16   10派10.20元(含税,扣税后9.18元)  0.036106  2.83  25.94  8.310811  12.624532
# 17            10派10.80元(含税)  0.033930  4.67  30.29  8.310603  15.788981
#
#        净利润同比增长         总股本       预案公告日       股权登记日       除权除息日     方案进度  \
# 0   583.829365  7700000000  2008-04-12  2008-06-16  2008-06-17     实施分配
# 1   -80.574496  7700000000  2009-04-11  2009-06-11  2009-06-12     实施分配
# 2   186.337096  8600000000  2010-04-19  2010-07-01  2010-07-02     实施分配
# 3    16.326808  8600000000  2011-03-28  2011-06-23  2011-06-24     实施分配
# 4    -2.851467  8600000000  2012-03-26  2012-06-21  2012-06-25     实施分配
# 5   -38.926982  9062000000  2013-03-25  2013-07-19  2013-07-22     实施分配
# 6    82.410873  9062000000  2014-03-31  2014-07-17  2014-07-18     实施分配
# 7    19.306770  9062000000  2015-03-30  2015-07-16  2015-07-17     实施分配
# 8    60.448909  9062000000  2016-03-28  2016-08-10  2016-08-11     实施分配
# 9   -31.988944  9062000000  2017-03-30  2017-08-01  2017-08-02     实施分配
# 10   21.605706  9062000000  2018-03-30  2018-08-07  2018-08-08     实施分配
# 11   22.895921  9062000000  2019-03-25  2019-07-22  2019-07-23     实施分配
# 12   53.954159  9062000000  2020-03-23  2020-06-10  2020-06-11     实施分配
# 13  -11.380267  9620341455  2021-03-29  2021-06-29  2021-06-30     实施分配
# 14    9.152294  9620341455  2022-03-28  2022-07-08  2022-07-11     实施分配
# 15   -8.291719  9620341455  2023-03-27  2023-06-28  2023-06-29     实施分配
# 16  -27.083278  9620341455  2024-03-29  2024-07-11  2024-07-12     实施分配
# 17   64.948454  9620341455  2025-03-27         NaT         NaT  董事会决议通过
#
#         最新公告日期
# 0   2008-06-11
# 1   2009-06-08
# 2   2010-06-28
# 3   2011-06-20
# 4   2012-06-18
# 5   2013-07-16
# 6   2014-07-14
# 7   2015-07-10
# 8   2016-08-04
# 9   2017-07-25
# 10  2018-07-31
# 11  2019-07-16
# 12  2020-06-03
# 13  2021-06-22
# 14  2022-07-01
# 15  2023-06-20
# 16  2024-07-05
# 17  2025-03-27

# %%
stock_fhps_detail_em_df
# Out:
#            报告期      业绩披露日期  送转股份-送转总比例  送转股份-送股比例  送转股份-转股比例  现金分红-现金分红比例  \
# 0   2007-12-31  2008-04-12         0.0        0.0        0.0          3.0
# 1   2008-12-31  2009-04-11         0.0        0.0        0.0          3.0
# 2   2009-12-31  2010-04-19         0.0        0.0        0.0          3.0
# 3   2010-12-31  2011-03-28         0.0        0.0        0.0          3.5
# 4   2011-12-31  2012-03-26         0.0        0.0        0.0          3.5
# 5   2012-12-31  2013-03-25         NaN        NaN        NaN          3.5
# 6   2013-12-31  2014-03-31         NaN        NaN        NaN          4.0
# 7   2014-12-31  2015-03-30         NaN        NaN        NaN          5.0
# 8   2015-12-31  2016-03-28         NaN        NaN        NaN         10.0
# 9   2016-12-31  2017-03-30         NaN        NaN        NaN          7.0
# 10  2017-12-31  2018-03-30         NaN        NaN        NaN          8.0
# 11  2018-12-31  2019-03-25         NaN        NaN        NaN         10.0
# 12  2019-12-31  2020-03-23         NaN        NaN        NaN         12.0
# 13  2020-12-31  2021-03-29         NaN        NaN        NaN         12.0
# 14  2021-12-31  2022-03-28         NaN        NaN        NaN         10.0
# 15  2022-12-31  2023-03-27         NaN        NaN        NaN         10.2
# 16  2023-12-31  2024-03-29         NaN        NaN        NaN         10.2
# 17  2024-12-31  2025-03-27         NaN        NaN        NaN         10.8
#
#               现金分红-现金分红比例描述  现金分红-股息率  每股收益  每股净资产     每股公积金    每股未分配利润  \
# 0     10派3.00元(含税,扣税后2.70元)  0.014918  1.12   8.16  6.400519   0.642468
# 1     10派3.00元(含税,扣税后2.70元)  0.014837  0.17   6.33  4.700649   0.504545
# 2     10派3.00元(含税,扣税后2.70元)  0.013187  0.95   8.80  6.748438   0.890251
# 3     10派3.50元(含税,扣税后3.15元)  0.016619  1.00   9.34  6.605814   1.537326
# 4     10派3.50元(含税,扣税后3.15元)  0.016174  0.97   8.93  5.584186   2.092209
# 5     10派3.50元(含税,扣税后3.15元)  0.021394  0.59  10.61  7.159126   2.162437
# 6     10派4.00元(含税,扣税后3.60元)  0.022284  1.02  10.92  6.796182   2.791216
# 7     10派5.00元(含税,扣税后4.50元)  0.017206  1.22  12.93  7.365041   2.945707
# 8    10派10.00元(含税,扣税后9.00元)  0.037010  1.96  14.71  7.365041   4.163319
# 9     10派7.00元(含税,扣税后6.30元)  0.019559  1.33  14.54  7.365041   4.278526
# 10    10派8.00元(含税,扣税后7.20元)  0.023966  1.62  15.17  7.350806   5.045465
# 11   10派10.00元(含税,扣税后9.00元)  0.026110  1.99  16.51  7.353233   6.026264
# 12  10派12.00元(含税,扣税后10.80元)  0.040134  3.06  19.69  7.354889   7.790995
# 13  10派12.00元(含税,扣税后10.80元)  0.039907  2.63  22.37  8.293971   8.475364
# 14   10派10.00元(含税,扣税后9.00元)  0.043706  2.79  23.57  8.280873   9.684927
# 15   10派10.20元(含税,扣税后9.18元)  0.037736  2.56  23.75  8.281185  10.936071
# 16   10派10.20元(含税,扣税后9.18元)  0.036106  2.83  25.94  8.310811  12.624532
# 17            10派10.80元(含税)  0.033930  4.67  30.29  8.310603  15.788981
#
#        净利润同比增长         总股本       预案公告日       股权登记日       除权除息日     方案进度  \
# 0   583.829365  7700000000  2008-04-12  2008-06-16  2008-06-17     实施分配
# 1   -80.574496  7700000000  2009-04-11  2009-06-11  2009-06-12     实施分配
# 2   186.337096  8600000000  2010-04-19  2010-07-01  2010-07-02     实施分配
# 3    16.326808  8600000000  2011-03-28  2011-06-23  2011-06-24     实施分配
# 4    -2.851467  8600000000  2012-03-26  2012-06-21  2012-06-25     实施分配
# 5   -38.926982  9062000000  2013-03-25  2013-07-19  2013-07-22     实施分配
# 6    82.410873  9062000000  2014-03-31  2014-07-17  2014-07-18     实施分配
# 7    19.306770  9062000000  2015-03-30  2015-07-16  2015-07-17     实施分配
# 8    60.448909  9062000000  2016-03-28  2016-08-10  2016-08-11     实施分配
# 9   -31.988944  9062000000  2017-03-30  2017-08-01  2017-08-02     实施分配
# 10   21.605706  9062000000  2018-03-30  2018-08-07  2018-08-08     实施分配
# 11   22.895921  9062000000  2019-03-25  2019-07-22  2019-07-23     实施分配
# 12   53.954159  9062000000  2020-03-23  2020-06-10  2020-06-11     实施分配
# 13  -11.380267  9620341455  2021-03-29  2021-06-29  2021-06-30     实施分配
# 14    9.152294  9620341455  2022-03-28  2022-07-08  2022-07-11     实施分配
# 15   -8.291719  9620341455  2023-03-27  2023-06-28  2023-06-29     实施分配
# 16  -27.083278  9620341455  2024-03-29  2024-07-11  2024-07-12     实施分配
# 17   64.948454  9620341455  2025-03-27         NaT         NaT  董事会决议通过
#
#         最新公告日期
# 0   2008-06-11
# 1   2009-06-08
# 2   2010-06-28
# 3   2011-06-20
# 4   2012-06-18
# 5   2013-07-16
# 6   2014-07-14
# 7   2015-07-10
# 8   2016-08-04
# 9   2017-07-25
# 10  2018-07-31
# 11  2019-07-16
# 12  2020-06-03
# 13  2021-06-22
# 14  2022-07-01
# 15  2023-06-20
# 16  2024-07-05
# 17  2025-03-27
