# %%
from pypekit import Task
import pandas as pd


class IrisLoader(Task):
    input_types = ["source"]
    output_types = ["raw"]

    def run(self, _):
        from sklearn.datasets import load_iris
        iris = load_iris()
        iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
        iris_df['target'] = iris.target
        return iris_df


class TrainTestSplitter(Task):
    input_types = ["raw"]
    output_types = ["split"]

    def run(self, df):
        from sklearn.model_selection import train_test_split
        train_df, test_df = train_test_split(df, test_size=0.2)
        train_df['train'] = 1
        test_df['train'] = 0
        df = pd.concat([train_df, test_df], ignore_index=True)
        return df


class Scaler(Task):
    input_types = ["split"]
    output_types = ["processed"]

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        X_train = X[df['train'] == 1]

        scaler = self.get_scaler()
        scaler.fit(X_train)

        X_scaled = scaler.transform(X)
        scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns)
        scaled_df['target'] = df['target']
        scaled_df['train'] = df['train']

        return scaled_df

    def get_scaler(self):
        raise NotImplementedError("Subclasses should implement this method.")


class MinMaxScaler(Scaler):
    def get_scaler(self):
        from sklearn.preprocessing import MinMaxScaler
        return MinMaxScaler()


class StandardScaler(Scaler):
    def get_scaler(self):
        from sklearn.preprocessing import StandardScaler
        return StandardScaler()


class PCA(Task):
    input_types = ["split", "processed"]
    output_types = ["processed"]

    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        X_train = X[df['train'] == 1]

        from sklearn.decomposition import PCA
        pca = PCA(**self.kwargs)
        pca.fit(X_train)

        X_pca = pca.transform(X)
        pca_df = pd.DataFrame(data=X_pca, columns=[
                              f'PC{i+1}' for i in range(X_pca.shape[1])])
        pca_df['target'] = df['target']
        pca_df['train'] = df['train']

        return pca_df


class Classifier(Task):
    input_types = ["split", "processed"]
    output_types = ["processed", "predicted"]

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        y = df['target']
        X_train = X[df['train'] == 1]
        y_train = y[df['train'] == 1]

        classifier = self.get_classifier()
        classifier.fit(X_train, y_train)
        
        y_pred = classifier.predict(X)
        df['predicted'] = y_pred

        return df
    
    def get_scaler(self):
        raise NotImplementedError("Subclasses should implement this method.")


class LogisticRegression(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.linear_model import LogisticRegression
        return LogisticRegression(**self.kwargs)


class RandomForestClassifier(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.ensemble import RandomForestClassifier
        return RandomForestClassifier(**self.kwargs)


class SVC(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.svm import SVC
        return SVC(**self.kwargs)


class Evaluator(Task):
    input_types = ["predicted"]
    output_types = ["sink"]

    def run(self, df):
        df_test = df[df['train'] == 0]
        return (df_test['target'] == df_test['predicted']).mean()

# %%
from pypekit import Repository, CachedExecutor

repository = Repository([
    ("data_loader", IrisLoader()),
    ("train_test_splitter", TrainTestSplitter()),
    ("minmax_scaler", MinMaxScaler()),
    ("standard_scaler", StandardScaler()),
    ("pca", PCA(n_components=2)),
    ("logistic_regression", LogisticRegression(max_iter=200)),
    ("random_forest", RandomForestClassifier(n_estimators=100)),
    ("svc", SVC(kernel='linear')),
    ("evaluator", Evaluator()),
])

pipeline_dict = repository.build_pipelines()
for pipeline in pipeline_dict.values():
    print(pipeline)
# Out:
# Pipeline(id=5a8deb1b5e84441b9f298f65f5b83acc, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=aa8a8f279aba45889fb03f1c286983fe, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=3ac58002889446e2ad36a2aa4708bdb6, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=6d44d7600b274c3b98da501864c26ceb, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=212ab338781741488bc9af875dcc5e08, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=34311650a6174f3f8913eb12e1e19d14, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=53974fe2c8034de79263458d8ce4bc80, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=a8c7aa61fa4c4a22850506983e7d7e46, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=7a497fdfed8a4b0594eec74d49fa8242, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=046c38eccfe64e2a97978b46fb192cac, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=5147f9a9f1a74d3bb759b54926270f41, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=2b00718b572e44c39d4317b5d7ffab98, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=5b9c19f1d58e4722bdbafd4190d414d4, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=006eb5cb74fe481491a186ca084a484a, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=58ff3d0af52748f0adf12e31d9c5fb85, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'evaluator'])
# Pipeline(id=ca4837f67242430c8b93cf6ac2373bad, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'pca', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=6675a909c7434e3ebe8a89ceb22f5113, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=3caea6437baf4ebe97bc3f2bcaf2b8ac, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'pca', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=90583e26a95045abad2258581e3145fa, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'pca', 'svc', 'evaluator'])
# Pipeline(id=d901bc5951774c71bd9a467bd71921b0, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'random_forest', 'pca', 'svc', 'evaluator'])
# Pipeline(id=dab309cc67ff4a6fb4e3629a4f357828, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=43afb9efa7104683811c64ba979ebab8, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=dabebe9eee7d4ad58132172ba918776b, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'svc', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=d63a119911da4d20ade3f617d13b0a88, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=fb83cf3502e848be888603fa62966f59, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=8df8c9532f9e409ab11229cb2d8ecae3, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'logistic_regression', 'evaluator'])
# Pipeline(id=2b7ceadcd511412a87a671b907562f98, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'pca', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=c80810cda6144642b4138b498ee9a75e, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=2f718fe372af4a1e85075b47e9113967, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'pca', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=ca1df031959140999c39d87d2702454b, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'pca', 'svc', 'evaluator'])
# Pipeline(id=4e9297103b0844ad955d01aa07646b9a, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'logistic_regression', 'pca', 'svc', 'evaluator'])
# Pipeline(id=54c150ff9381421fae06669a54fe673c, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=97911349e5d4460ebcc1d5aa4e877b6e, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=bb0a0b64b3204152a0860da3a15347b0, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'svc', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=4ba6c3d091ee4b9cb045d0cf075b07ed, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=0ed58ef9c44349feadd4559e0a41d572, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=c8a9e2c162374d258603ef72f28d5bb3, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'random_forest', 'evaluator'])
# Pipeline(id=0574ce5b464d4e7aa219df97e4b7cee9, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'pca', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=055a48874bac4b0bb56577b38cdf71e1, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=35290eb2f09e4162bcdf3f134275c88d, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'pca', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=7928abaaf1a249859fdb1a8fee41f087, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=65de75ba35bd40f9bbc6b0d298eccb80, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'logistic_regression', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=09fe408051ff43bb87c130e81e83b456, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=8c2ef8fcb9ad4cf79ab27fcf25685a90, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=7677fa2d4180470d8d39b34c963ce9c0, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'random_forest', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=63f37bbaa00c444fad5d26e215246077, tasks=['data_loader', 'train_test_splitter', 'minmax_scaler', 'svc', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id
 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=d8500aa939944ad1a9ca1a9863928333, tasks=['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=b80de955f4c34344b036220e8a835862, tasks=['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=71dcde0e41e942ec82108d9b1e29fa88, tasks=['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=c2c4dbaf99ee40d59fc33431bf5bd1df, tasks=['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=9752214e11a2419fb84fbf1351de6ac6, tasks=['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=1613cea9ec674671b445b76183492b98, tasks=['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=c10ad03b6a8042829174b2700388a4ca, tasks=['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=5578e0a16fbc443782a1b82e60a7727d, tasks=['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=a48334292ae6494e9975da860a27581b, tasks=['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=8bdfd1a4a05e49288cb16006edc0eae2, tasks=['data_loader', 'train_test_splitter', 'pca', 'svc', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=b2b21140a7fa4b01a7599bc50e5c30f3, tasks=['data_loader', 'train_test_splitter', 'pca', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=b0184c991f314f49a6b1cb6f1955ac0c, tasks=['data_loader', 'train_test_splitter', 'pca', 'svc', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=355f6f2777424b6d92f445527b116735, tasks=['data_loader', 'train_test_splitter', 'pca', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=24cd5c4173564a969de73d9f0b239922, tasks=['data_loader', 'train_test_splitter', 'pca', 'svc', 'evaluator'])
# Pipeline(id=1996ad0b521747238e6693f24d87f6b4, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=309db9ca5a4d483c96bb1635708b99e3, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=748bc6181be346f189295b4d9abf4052, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=59e201bee3534628aba76f8e22158d41, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'svc', 'evaluator'])
# Pipeline(id=2853398936bd40a69ac4c4ccab0e4236, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'random_forest', 'pca', 'svc', 'evaluator'])
# Pipeline(id=57394001a5514e50bce5ed79af7436bb, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=b5d6c89d1cd94a30b41dedca522f1807, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=28daef973d774092934725698d334f6a, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'svc', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=fdf7bd9702b643f4ac0679c6e51b7a50, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=d1f9ea2f305f47a496e5e406feda4aa9, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=db12d6bd49a241aead12461c7da2eb08, tasks=['data_loader', 'train_test_splitter', 'logistic_regression', 'evaluator'])
# Pipeline(id=9f7be447b46f4578a68a8722b0f03192, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=bbccdb885d6d427a907b31921f84c967, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=ce3ef6c19c46449b8ba9d07452099100, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=11639f0451ad4335b016196c4455c036, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'svc', 'evaluator'])
# Pipeline(id=9c2eae66a07444a3b1ae477fa67febfb, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'logistic_regression', 'pca', 'svc', 'evaluator'])
# Pipeline(id=715611e34d0042c9843e9d5144249982, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'logistic_regression', 'svc', 'evaluator'])
# Pipeline(id=79901119c18840ddba8fa4f3c3e72a9c, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=6d5417d44f5d40dba56d7b4ab79d3824, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'svc', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=bb6ded1b9262444e8a71b9f21dab8d21, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=6711a99956724242b2a2303dc1c68375, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'svc', 'evaluator'])
# Pipeline(id=df887af545fd45c9b0b2589a457b51b5, tasks=['data_loader', 'train_test_splitter', 'random_forest', 'evaluator'])
# Pipeline(id=5321bb3672af47098d5d03e5f3cb98f3, tasks=['data_loader', 'train_test_splitter', 'svc', 'pca', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=106a4a97a62c4f76a5c384d57e78c2a4, tasks=['data_loader', 'train_test_splitter', 'svc', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=d007697392b04850a8f06388622d31d6, tasks=['data_loader', 'train_test_splitter', 'svc', 'pca', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=8f73c10c4b184a96a112b8e4842dcc28, tasks=['data_loader', 'train_test_splitter', 'svc', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=3d723a901ae54c638dfa8fd1df14362a, tasks=['data_loader', 'train_test_splitter', 'svc', 'logistic_regression', 'pca', 'random_forest', 'evaluator'])
# Pipeline(id=af483964dd544a5caa980850790e1865, tasks=['data_loader', 'train_test_splitter', 'svc', 'logistic_regression', 'random_forest', 'evaluator'])
# Pipeline(id=51b8fdb57cb147daafefa12a7be80a3d, tasks=['data_loader', 'train_test_splitter', 'svc', 'logistic_regression', 'evaluator'])
# Pipeline(id=1ebcfe07f1fb445aaae03e9efb3b440d, tasks=['data_loader', 'train_test_splitter', 'svc', 'random_forest', 'pca', 'logistic_regression', 'evaluator'])
# Pipeline(id=a9c8a38f69e7431aa06237bdccb411ae, tasks=['data_loader', 'train_test_splitter', 'svc', 'random_forest', 'logistic_regression', 'evaluator'])
# Pipeline(id=e94985313b2646678b7906bf9673aa1f, tasks=['data_loader', 'train_test_splitter', 'svc', 'random_forest', 'evaluator'])
# Pipeline(id=73ac8d3bdcf84984a2452f86fbe9d7db, tasks=['data_loader', 'train_test_splitter', 'svc', 'evaluator'])

# %%
executor = CachedExecutor(pipeline_dict, verbose=True)
results = executor.run()
# Out:
# Ran pipeline 5a8deb1b5e84441b9f298f65f5b83acc. Runtime: 2.45s. 1/144 pipelines completed.
# Ran pipeline aa8a8f279aba45889fb03f1c286983fe. Runtime: 2.44s. 2/144 pipelines completed.
# Ran pipeline 3ac58002889446e2ad36a2aa4708bdb6. Runtime: 1.72s. 3/144 pipelines completed.
# Ran pipeline 6d44d7600b274c3b98da501864c26ceb. Runtime: 1.66s. 4/144 pipelines completed.
# Ran pipeline 212ab338781741488bc9af875dcc5e08. Runtime: 1.66s. 5/144 pipelines completed.
# Ran pipeline 34311650a6174f3f8913eb12e1e19d14. Runtime: 1.73s. 6/144 pipelines completed.
# Ran pipeline 53974fe2c8034de79263458d8ce4bc80. Runtime: 1.69s. 7/144 pipelines completed.
# Ran pipeline a8c7aa61fa4c4a22850506983e7d7e46. Runtime: 1.69s. 8/144 pipelines completed.
# Ran pipeline 7a497fdfed8a4b0594eec74d49fa8242. Runtime: 1.69s. 9/144 pipelines completed.
# Ran pipeline 046c38eccfe64e2a97978b46fb192cac. Runtime: 1.68s. 10/144 pipelines completed.
# Ran pipeline 5147f9a9f1a74d3bb759b54926270f41. Runtime: 2.55s. 11/144 pipelines completed.
# Ran pipeline 2b00718b572e44c39d4317b5d7ffab98. Runtime: 1.72s. 12/144 pipelines completed.
# Ran pipeline 5b9c19f1d58e4722bdbafd4190d414d4. Runtime: 1.70s. 13/144 pipelines completed.
# Ran pipeline 006eb5cb74fe481491a186ca084a484a. Runtime: 1.69s. 14/144 pipelines completed.
# Ran pipeline 58ff3d0af52748f0adf12e31d9c5fb85. Runtime: 1.63s. 15/144 pipelines completed.
# Ran pipeline ca4837f67242430c8b93cf6ac2373bad. Runtime: 2.48s. 16/144 pipelines completed.
# Ran pipeline 6675a909c7434e3ebe8a89ceb22f5113. Runtime: 2.41s. 17/144 pipelines completed.
# Ran pipeline 3caea6437baf4ebe97bc3f2bcaf2b8ac. Runtime: 1.67s. 18/144 pipelines completed.
# Ran pipeline 90583e26a95045abad2258581e3145fa. Runtime: 1.61s. 19/144 pipelines completed.
# Ran pipeline d901bc5951774c71bd9a467bd71921b0. Runtime: 1.68s. 20/144 pipelines completed.
# Ran pipeline dab309cc67ff4a6fb4e3629a4f357828. Runtime: 1.67s. 21/144 pipelines completed.
# Ran pipeline 43afb9efa7104683811c64ba979ebab8. Runtime: 1.67s. 22/144 pipelines completed.
# Ran pipeline dabebe9eee7d4ad58132172ba918776b. Runtime: 1.67s. 23/144 pipelines completed.
# Ran pipeline d63a119911da4d20ade3f617d13b0a88. Runtime: 1.67s. 24/144 pipelines completed.
# Ran pipeline fb83cf3502e848be888603fa62966f59. Runtime: 1.61s. 25/144 pipelines completed.
# Ran pipeline 8df8c9532f9e409ab11229cb2d8ecae3. Runtime: 1.61s. 26/144 pipelines completed.
# Ran pipeline 2b7ceadcd511412a87a671b907562f98. Runtime: 1.71s. 27/144 pipelines completed.
# Ran pipeline c80810cda6144642b4138b498ee9a75e. Runtime: 1.68s. 28/144 pipelines completed.
# Ran pipeline 2f718fe372af4a1e85075b47e9113967. Runtime: 1.68s. 29/144 pipelines completed.
# Ran pipeline ca1df031959140999c39d87d2702454b. Runtime: 1.68s. 30/144 pipelines completed.
# Ran pipeline 4e9297103b0844ad955d01aa07646b9a. Runtime: 1.77s. 31/144 pipelines completed.
# Ran pipeline 54c150ff9381421fae06669a54fe673c. Runtime: 1.77s. 32/144 pipelines completed.
# Ran pipeline 97911349e5d4460ebcc1d5aa4e877b6e. Runtime: 1.86s. 33/144 pipelines completed.
# Ran pipeline bb0a0b64b3204152a0860da3a15347b0. Runtime: 1.68s. 34/144 pipelines completed.
# Ran pipeline 4ba6c3d091ee4b9cb045d0cf075b07ed. Runtime: 1.77s. 35/144 pipelines completed.
# Ran pipeline 0ed58ef9c44349feadd4559e0a41d572. Runtime: 1.67s. 36/144 pipelines completed.
# Ran pipeline c8a9e2c162374d258603ef72f28d5bb3. Runtime: 1.67s. 37/144 pipelines completed.
# Ran pipeline 0574ce5b464d4e7aa219df97e4b7cee9. Runtime: 2.42s. 38/144 pipelines completed.
# Ran pipeline 055a48874bac4b0bb56577b38cdf71e1. Runtime: 1.71s. 39/144 pipelines completed.
# Ran pipeline 35290eb2f09e4162bcdf3f134275c88d. Runtime: 1.79s. 40/144 pipelines completed.
# Ran pipeline 7928abaaf1a249859fdb1a8fee41f087. Runtime: 1.78s. 41/144 pipelines completed.
# Ran pipeline 65de75ba35bd40f9bbc6b0d298eccb80. Runtime: 2.37s. 42/144 pipelines completed.
# Ran pipeline 09fe408051ff43bb87c130e81e83b456. Runtime: 1.82s. 43/144 pipelines completed.
# Ran pipeline 8c2ef8fcb9ad4cf79ab27fcf25685a90. Runtime: 1.66s. 44/144 pipelines completed.
# Ran pipeline 7677fa2d4180470d8d39b34c963ce9c0. Runtime: 1.67s. 45/144 pipelines completed.
# Ran pipeline 63f37bbaa00c444fad5d26e215246077. Runtime: 1.67s. 46/144 pipelines completed.
# Ran pipeline cbeea3826f0d409eac5a84afbc8c96d0. Runtime: 1.66s. 47/144 pipelines completed.
# Ran pipeline e684f45c99144a0d9f1572570ab2b85c. Runtime: 1.61s. 48/144 pipelines completed.
# Ran pipeline 25db51af81974b9a920c7f1f2a7ed7a1. Runtime: 2.32s. 49/144 pipelines completed.
# Ran pipeline a30b359394014620ba1be0b83cf7b054. Runtime: 2.32s. 50/144 pipelines completed.
# Ran pipeline 39e1cc65ad21471b898770bbd21b730b. Runtime: 1.85s. 51/144 pipelines completed.
# Ran pipeline 1de416217e2c44f8996599708bdfe25a. Runtime: 1.70s. 52/144 pipelines completed.
# Ran pipeline 08920b501f764068a15d70779de0408e. Runtime: 1.61s. 53/144 pipelines completed.
# Ran pipeline c41498a3bad242d187ef3c07be95d15e. Runtime: 1.67s. 54/144 pipelines completed.
# Ran pipeline 46cebf8ee4fb481e9327fff5c5fe8a12. Runtime: 1.67s. 55/144 pipelines completed.
# Ran pipeline 6ca6f2b1c2344c509a007c7bd0406ddc. Runtime: 1.71s. 56/144 pipelines completed.
# Ran pipeline a643d7fc11424b0bb97baa1465776b28. Runtime: 1.71s. 57/144 pipelines completed.
# Ran pipeline 5de158d118cf49ccb9ee8f1dcecaf249. Runtime: 1.66s. 58/144 pipelines completed.
# Ran pipeline 5a3bc4c0369b48bc89552174723dd9a2. Runtime: 2.42s. 59/144 pipelines completed.
# Ran pipeline f4117569be8a4f7a88799de9511ad406. Runtime: 1.70s. 60/144 pipelines completed.
# Ran pipeline 68675d48eba5441081c417d012031d8c. Runtime: 1.76s. 61/144 pipelines completed.
# Ran pipeline 8ddaffbaff2247ad8c9351a3c1471e3b. Runtime: 1.76s. 62/144 pipelines completed.
# Ran pipeline 04b8bf0e6a5e40738197e1273be7f30a. Runtime: 1.61s. 63/144 pipelines completed.
# Ran pipeline e66b5aee83854a20980e0c13c6c97324. Runtime: 2.39s. 64/144 pipelines completed.
# Ran pipeline 9951f18051914d22aad6400fb82e845c. Runtime: 2.38s. 65/144 pipelines completed.
# Ran pipeline 8e3ec18881284030ad73d0abd4b17d30. Runtime: 1.81s. 66/144 pipelines completed.
# Ran pipeline f9363156ecba4380a97ea16c235e6b6f. Runtime: 1.76s. 67/144 pipelines completed.
# Ran pipeline 41d5cc7d9b974d48897bcbfae68da789. Runtime: 1.67s. 68/144 pipelines completed.
# Ran pipeline f68618e9d5a0465f8a0c6a509bbe9f40. Runtime: 1.67s. 69/144 pipelines completed.
# Ran pipeline b1fca8265f294ee5a7b0c3785b6dab2d. Runtime: 1.66s. 70/144 pipelines completed.
# Ran pipeline 58fbaa4bb33344f1bc8f0968de734307. Runtime: 1.67s. 71/144 pipelines completed.
# Ran pipeline 2355c5de7cdc40e3ba472127e8351917. Runtime: 1.67s. 72/144 pipelines completed.
# Ran pipeline f1e1e967344549478446bbc2e1de0cc9. Runtime: 1.61s. 73/144 pipelines completed.
# Ran pipeline 2a3c9ce14cdb4fc3914e02fceffea639. Runtime: 1.61s. 74/144 pipelines completed.
# Ran pipeline ddfdb1ccfcae4689a083c808fa4700b7. Runtime: 1.68s. 75/144 pipelines completed.
# Ran pipeline 6d5fca7fbd8c4b2686bada1ce93f8d43. Runtime: 1.67s. 76/144 pipelines completed.
# Ran pipeline 054b19ed955a4fb1ad82ba2063f75147. Runtime: 1.67s. 77/144 pipelines completed.
# Ran pipeline 068f95d77e5c4e00b339ac39199f6d2e. Runtime: 1.66s. 78/144 pipelines completed.
# Ran pipeline 7a04f485a1014eb7a1220eb0f11e496a. Runtime: 1.76s. 79/144 pipelines completed.
# Ran pipeline 28ee11ebd8c9495db1b13146aa65117b. Runtime: 1.67s. 80/144 pipelines completed.
# Ran pipeline 3ec305d8a525414db2087bee30fa318c. Runtime: 1.66s. 81/144 pipelines completed.
# Ran pipeline 90f74a4f7e264d8f83c23a0d19ebac71. Runtime: 1.76s. 82/144 pipelines completed.
# Ran pipeline 88f4887925504e7dbceb9dd83fa0963e. Runtime: 1.67s. 83/144 pipelines completed.
# Ran pipeline 0793e019d07744a788e4849e282079d9. Runtime: 1.66s. 84/144 pipelines completed.
# Ran pipeline 0029b3ee36d74160a6794be0431e7790. Runtime: 1.66s. 85/144 pipelines completed.
# Ran pipeline e19bfc9c331142aab9a5661aaa5284fc. Runtime: 2.42s. 86/144 pipelines completed.
# Ran pipeline e30e0b23cf8a47358736dea5762df138. Runtime: 1.70s. 87/144 pipelines completed.
# Ran pipeline 507ac86b10554a1d863a26b7766260aa. Runtime: 1.78s. 88/144 pipelines completed.
# Ran pipeline fff1336f3c5241b8a73f6a795c9a3473. Runtime: 1.77s. 89/144 pipelines completed.
# Ran pipeline 3c7596fedf5d4d12a31c34c7f1a8b047. Runtime: 2.36s. 90/144 pipelines completed.
# Ran pipeline 5da72160ef6b40f084e6bec76c791720. Runtime: 1.81s. 91/144 pipelines completed.
# Ran pipeline 6ad2d54e13b446bab1bf038eb3076157. Runtime: 1.64s. 92/144 pipelines completed.
# Ran pipeline 171bc465043249f5854485325812c90d. Runtime: 1.67s. 93/144 pipelines completed.
# Ran pipeline a198ece56ea747d99e6cfedefe20fcbd. Runtime: 1.74s. 94/144 pipelines completed.
# Ran pipeline e711b47839f249a89793c8228f9ff7d3. Runtime: 1.66s. 95/144 pipelines completed.
# Ran pipeline 2d9463dd2a9143a28e85c299f7b11bc5. Runtime: 1.61s. 96/144 pipelines completed.
# Ran pipeline e58bfded78c4464fa0699de074ce04c8. Runtime: 2.47s. 97/144 pipelines completed.
# Ran pipeline d8500aa939944ad1a9ca1a9863928333. Runtime: 2.42s. 98/144 pipelines completed.
# Ran pipeline b80de955f4c34344b036220e8a835862. Runtime: 1.67s. 99/144 pipelines completed.
# Ran pipeline 71dcde0e41e942ec82108d9b1e29fa88. Runtime: 1.61s. 100/144 pipelines completed.
# Ran pipeline c2c4dbaf99ee40d59fc33431bf5bd1df. Runtime: 1.61s. 101/144 pipelines completed.
# Ran pipeline 9752214e11a2419fb84fbf1351de6ac6. Runtime: 1.71s. 102/144 pipelines completed.
# Ran pipeline 1613cea9ec674671b445b76183492b98. Runtime: 1.67s. 103/144 pipelines completed.
# Ran pipeline c10ad03b6a8042829174b2700388a4ca. Runtime: 1.67s. 104/144 pipelines completed.
# Ran pipeline 5578e0a16fbc443782a1b82e60a7727d. Runtime: 1.67s. 105/144 pipelines completed.
# Ran pipeline a48334292ae6494e9975da860a27581b. Runtime: 1.76s. 106/144 pipelines completed.
# Ran pipeline 8bdfd1a4a05e49288cb16006edc0eae2. Runtime: 2.43s. 107/144 pipelines completed.
# Ran pipeline b2b21140a7fa4b01a7599bc50e5c30f3. Runtime: 1.68s. 108/144 pipelines completed.
# Ran pipeline b0184c991f314f49a6b1cb6f1955ac0c. Runtime: 1.67s. 109/144 pipelines completed.
# Ran pipeline 355f6f2777424b6d92f445527b116735. Runtime: 1.66s. 110/144 pipelines completed.
# Ran pipeline 24cd5c4173564a969de73d9f0b239922. Runtime: 1.61s. 111/144 pipelines completed.
# Ran pipeline 1996ad0b521747238e6693f24d87f6b4. Runtime: 2.50s. 112/144 pipelines completed.
# Ran pipeline 309db9ca5a4d483c96bb1635708b99e3. Runtime: 2.50s. 113/144 pipelines completed.
# Ran pipeline 748bc6181be346f189295b4d9abf4052. Runtime: 1.73s. 114/144 pipelines completed.
# Ran pipeline 59e201bee3534628aba76f8e22158d41. Runtime: 1.67s. 115/144 pipelines completed.
# Ran pipeline 2853398936bd40a69ac4c4ccab0e4236. Runtime: 1.73s. 116/144 pipelines completed.
# Ran pipeline 57394001a5514e50bce5ed79af7436bb. Runtime: 1.73s. 117/144 pipelines completed.
# Ran pipeline b5d6c89d1cd94a30b41dedca522f1807. Runtime: 1.72s. 118/144 pipelines completed.
# Ran pipeline 28daef973d774092934725698d334f6a. Runtime: 1.73s. 119/144 pipelines completed.
# Ran pipeline fdf7bd9702b643f4ac0679c6e51b7a50. Runtime: 1.73s. 120/144 pipelines completed.
# Ran pipeline d1f9ea2f305f47a496e5e406feda4aa9. Runtime: 1.67s. 121/144 pipelines completed.
# Ran pipeline db12d6bd49a241aead12461c7da2eb08. Runtime: 1.67s. 122/144 pipelines completed.
# Ran pipeline 9f7be447b46f4578a68a8722b0f03192. Runtime: 1.67s. 123/144 pipelines completed.
# Ran pipeline bbccdb885d6d427a907b31921f84c967. Runtime: 1.67s. 124/144 pipelines completed.
# Ran pipeline ce3ef6c19c46449b8ba9d07452099100. Runtime: 1.71s. 125/144 pipelines completed.
# Ran pipeline 11639f0451ad4335b016196c4455c036. Runtime: 1.71s. 126/144 pipelines completed.
# Ran pipeline 9c2eae66a07444a3b1ae477fa67febfb. Runtime: 1.76s. 127/144 pipelines completed.
# Ran pipeline 715611e34d0042c9843e9d5144249982. Runtime: 1.67s. 128/144 pipelines completed.
# Ran pipeline 79901119c18840ddba8fa4f3c3e72a9c. Runtime: 1.67s. 129/144 pipelines completed.
# Ran pipeline 6d5417d44f5d40dba56d7b4ab79d3824. Runtime: 1.76s. 130/144 pipelines completed.
# Ran pipeline bb6ded1b9262444e8a71b9f21dab8d21. Runtime: 1.67s. 131/144 pipelines completed.
# Ran pipeline 6711a99956724242b2a2303dc1c68375. Runtime: 1.66s. 132/144 pipelines completed.
# Ran pipeline df887af545fd45c9b0b2589a457b51b5. Runtime: 1.66s. 133/144 pipelines completed.
# Ran pipeline 5321bb3672af47098d5d03e5f3cb98f3. Runtime: 2.41s. 134/144 pipelines completed.
# Ran pipeline 106a4a97a62c4f76a5c384d57e78c2a4. Runtime: 1.70s. 135/144 pipelines completed.
# Ran pipeline d007697392b04850a8f06388622d31d6. Runtime: 1.90s. 136/144 pipelines completed.
# Ran pipeline 8f73c10c4b184a96a112b8e4842dcc28. Runtime: 1.89s. 137/144 pipelines completed.
# Ran pipeline 3d723a901ae54c638dfa8fd1df14362a. Runtime: 2.48s. 138/144 pipelines completed.
# Ran pipeline af483964dd544a5caa980850790e1865. Runtime: 1.94s. 139/144 pipelines completed.
# Ran pipeline 51b8fdb57cb147daafefa12a7be80a3d. Runtime: 1.77s. 140/144 pipelines completed.
# Ran pipeline 1ebcfe07f1fb445aaae03e9efb3b440d. Runtime: 1.76s. 141/144 pipelines completed.
# Ran pipeline a9c8a38f69e7431aa06237bdccb411ae. Runtime: 1.81s. 142/144 pipelines completed.
# Ran pipeline e94985313b2646678b7906bf9673aa1f. Runtime: 1.75s. 143/144 pipelines completed.
# Ran pipeline 73ac8d3bdcf84984a2452f86fbe9d7db. Runtime: 1.70s. 144/144 pipelines completed.

# %%
for result in results.values():
    print(result)
# Out:
# {'pipeline_id': '5a8deb1b5e84441b9f298f65f5b83acc', 'output': np.float64(0.9333333333333333), 'runtime': 2.4475462, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': 'aa8a8f279aba45889fb03f1c286983fe', 'output': np.float64(0.9333333333333333), 'runtime': 2.4445745999999997, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': '3ac58002889446e2ad36a2aa4708bdb6', 'output': np.float64(0.9333333333333333), 'runtime': 1.7210162999999987, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': '6d44d7600b274c3b98da501864c26ceb', 'output': np.float64(0.9333333333333333), 'runtime': 1.6625276999999992, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': '212ab338781741488bc9af875dcc5e08', 'output': np.float64(0.9333333333333333), 'runtime': 1.6599703999999997, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '34311650a6174f3f8913eb12e1e19d14', 'output': np.float64(0.9333333333333333), 'runtime': 1.7295957999999998, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': '53974fe2c8034de79263458d8ce4bc80', 'output': np.float64(0.9333333333333333), 'runtime': 1.6889858000000006, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'a8c7aa61fa4c4a22850506983e7d7e46', 'output': np.float64(0.9333333333333333), 'runtime': 1.6879167000000002, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '7a497fdfed8a4b0594eec74d49fa8242', 'output': np.float64(0.9333333333333333), 'runtime': 1.6852762999999995, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': '046c38eccfe64e2a97978b46fb192cac', 'output': np.float64(0.9333333333333333), 'runtime': 1.6834307000000002, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': '5147f9a9f1a74d3bb759b54926270f41', 'output': np.float64(0.9333333333333333), 'runtime': 2.546121399999999, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': '2b00718b572e44c39d4317b5d7ffab98', 'output': np.float64(0.9333333333333333), 'runtime': 1.7233748999999992, 'tasks': ['data_loader', 'train_test_splitter', 'minmax_scaler', 'pca', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id':
 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'pca', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'fff1336f3c5241b8a73f6a795c9a3473', 'output': np.float64(0.9666666666666667), 'runtime': 1.7718986999999995, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': '3c7596fedf5d4d12a31c34c7f1a8b047', 'output': np.float64(0.9666666666666667), 'runtime': 2.3573287999999994, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'logistic_regression', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': '5da72160ef6b40f084e6bec76c791720', 'output': np.float64(0.9666666666666667), 'runtime': 1.8095876000000004, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': '6ad2d54e13b446bab1bf038eb3076157', 'output': np.float64(0.9666666666666667), 'runtime': 1.6414150999999997, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '171bc465043249f5854485325812c90d', 'output': np.float64(0.9666666666666667), 'runtime': 1.6703747, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'random_forest', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'a198ece56ea747d99e6cfedefe20fcbd', 'output': np.float64(0.9666666666666667), 'runtime': 1.7374233000000014, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'e711b47839f249a89793c8228f9ff7d3', 'output': np.float64(0.9666666666666667), 'runtime': 1.6637801000000003, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': '2d9463dd2a9143a28e85c299f7b11bc5', 'output': np.float64(0.9666666666666667), 'runtime': 1.6075755999999988, 'tasks': ['data_loader', 'train_test_splitter', 'standard_scaler', 'svc', 'evaluator']}
# {'pipeline_id': 'e58bfded78c4464fa0699de074ce04c8', 'output': np.float64(0.9666666666666667), 'runtime': 2.472680099999998, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': 'd8500aa939944ad1a9ca1a9863928333', 'output': np.float64(0.9666666666666667), 'runtime': 2.4194835, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': 'b80de955f4c34344b036220e8a835862', 'output': np.float64(0.9666666666666667), 'runtime': 1.6680503999999985, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': '71dcde0e41e942ec82108d9b1e29fa88', 'output': np.float64(0.9666666666666667), 'runtime': 1.611279999999999, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': 'c2c4dbaf99ee40d59fc33431bf5bd1df', 'output': np.float64(0.9666666666666667), 'runtime': 1.6093384999999998, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '9752214e11a2419fb84fbf1351de6ac6', 'output': np.float64(0.9666666666666667), 'runtime': 1.712966100000001, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': '1613cea9ec674671b445b76183492b98', 'output': np.float64(0.9666666666666667), 'runtime': 1.6711305000000003, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'c10ad03b6a8042829174b2700388a4ca', 'output': np.float64(0.9666666666666667), 'runtime': 1.6724357999999988, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '5578e0a16fbc443782a1b82e60a7727d', 'output': np.float64(0.9666666666666667), 'runtime': 1.667576799999999, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': 'a48334292ae6494e9975da860a27581b', 'output': np.float64(0.9666666666666667), 'runtime': 1.756468100000001, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': '8bdfd1a4a05e49288cb16006edc0eae2', 'output': np.float64(0.9666666666666667), 'runtime': 2.4267524, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'svc', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': 'b2b21140a7fa4b01a7599bc50e5c30f3', 'output': np.float64(0.9666666666666667), 'runtime': 1.6833571000000003, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'b0184c991f314f49a6b1cb6f1955ac0c', 'output': np.float64(0.9666666666666667), 'runtime': 1.667871100000001, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'svc', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '355f6f2777424b6d92f445527b116735', 'output': np.float64(0.9666666666666667), 'runtime': 1.6636499000000011, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': '24cd5c4173564a969de73d9f0b239922', 'output': np.float64(0.9666666666666667), 'runtime': 1.609405599999997, 'tasks': ['data_loader', 'train_test_splitter', 'pca', 'svc', 'evaluator']}
# {'pipeline_id': '1996ad0b521747238e6693f24d87f6b4', 'output': np.float64(0.9333333333333333), 'runtime': 2.5025299000000025, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': '309db9ca5a4d483c96bb1635708b99e3', 'output': np.float64(0.9333333333333333), 'runtime': 2.4998397000000026, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': '748bc6181be346f189295b4d9abf4052', 'output': np.float64(0.9333333333333333), 'runtime': 1.7287256000000006, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': '59e201bee3534628aba76f8e22158d41', 'output': np.float64(0.9333333333333333), 'runtime': 1.6731000000000016, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'pca', 'svc', 'evaluator']}
# {'pipeline_id': '2853398936bd40a69ac4c4ccab0e4236', 'output': np.float64(0.9666666666666667), 'runtime': 1.7277991000000021, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'random_forest', 'pca', 'svc', 'evaluator']}
# {'pipeline_id': '57394001a5514e50bce5ed79af7436bb', 'output': np.float64(0.9666666666666667), 'runtime': 1.7259177000000037, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': 'b5d6c89d1cd94a30b41dedca522f1807', 'output': np.float64(0.9666666666666667), 'runtime': 1.7242603000000045, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': '28daef973d774092934725698d334f6a', 'output': np.float64(0.9666666666666667), 'runtime': 1.7259677999999994, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'svc', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': 'fdf7bd9702b643f4ac0679c6e51b7a50', 'output': np.float64(0.9666666666666667), 'runtime': 1.7274171999999979, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': 'd1f9ea2f305f47a496e5e406feda4aa9', 'output': np.float64(0.9666666666666667), 'runtime': 1.669763599999996, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': 'db12d6bd49a241aead12461c7da2eb08', 'output': np.float64(0.9666666666666667), 'runtime': 1.6677378000000012, 'tasks': ['data_loader', 'train_test_splitter', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '9f7be447b46f4578a68a8722b0f03192', 'output': np.float64(0.9666666666666667), 'runtime': 1.6687301999999988, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': 'bbccdb885d6d427a907b31921f84c967', 'output': np.float64(0.9666666666666667), 'runtime': 1.6669029000000002, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'ce3ef6c19c46449b8ba9d07452099100', 'output': np.float64(0.9666666666666667), 'runtime': 1.7147691999999992, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '11639f0451ad4335b016196c4455c036', 'output': np.float64(0.9666666666666667), 'runtime': 1.7117134999999983, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'pca', 'svc', 'evaluator']}
# {'pipeline_id': '9c2eae66a07444a3b1ae477fa67febfb', 'output': np.float64(0.9666666666666667), 'runtime': 1.7630262999999964, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'logistic_regression', 'pca', 'svc', 'evaluator']}
# {'pipeline_id': '715611e34d0042c9843e9d5144249982', 'output': np.float64(0.9666666666666667), 'runtime': 1.6696619999999989, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'logistic_regression', 'svc', 'evaluator']}
# {'pipeline_id': '79901119c18840ddba8fa4f3c3e72a9c', 'output': np.float64(0.9666666666666667), 'runtime': 1.667943600000001, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '6d5417d44f5d40dba56d7b4ab79d3824', 'output': np.float64(0.9666666666666667), 'runtime': 1.759764299999997, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'svc', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'bb6ded1b9262444e8a71b9f21dab8d21', 'output': np.float64(0.9666666666666667), 'runtime': 1.6698990999999985, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '6711a99956724242b2a2303dc1c68375', 'output': np.float64(0.9666666666666667), 'runtime': 1.6637638999999993, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'svc', 'evaluator']}
# {'pipeline_id': 'df887af545fd45c9b0b2589a457b51b5', 'output': np.float64(0.9666666666666667), 'runtime': 1.6616676000000012, 'tasks': ['data_loader', 'train_test_splitter', 'random_forest', 'evaluator']}
# {'pipeline_id': '5321bb3672af47098d5d03e5f3cb98f3', 'output': np.float64(0.9666666666666667), 'runtime': 2.4087624999999946, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'pca', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': '106a4a97a62c4f76a5c384d57e78c2a4', 'output': np.float64(0.9666666666666667), 'runtime': 1.7016138999999946, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'd007697392b04850a8f06388622d31d6', 'output': np.float64(0.9666666666666667), 'runtime': 1.8967387999999978, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'pca', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '8f73c10c4b184a96a112b8e4842dcc28', 'output': np.float64(0.9666666666666667), 'runtime': 1.8920242999999957, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': '3d723a901ae54c638dfa8fd1df14362a', 'output': np.float64(0.9666666666666667), 'runtime': 2.484626800000001, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'logistic_regression', 'pca', 'random_forest', 'evaluator']}
# {'pipeline_id': 'af483964dd544a5caa980850790e1865', 'output': np.float64(0.9666666666666667), 'runtime': 1.9361023999999958, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'logistic_regression', 'random_forest', 'evaluator']}
# {'pipeline_id': '51b8fdb57cb147daafefa12a7be80a3d', 'output': np.float64(0.9666666666666667), 'runtime': 1.7678821999999954, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'logistic_regression', 'evaluator']}
# {'pipeline_id': '1ebcfe07f1fb445aaae03e9efb3b440d', 'output': np.float64(0.9666666666666667), 'runtime': 1.7582803999999967, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'random_forest', 'pca', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'a9c8a38f69e7431aa06237bdccb411ae', 'output': np.float64(0.9666666666666667), 'runtime': 1.8084302, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'random_forest', 'logistic_regression', 'evaluator']}
# {'pipeline_id': 'e94985313b2646678b7906bf9673aa1f', 'output': np.float64(0.9666666666666667), 'runtime': 1.7526418999999969, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'random_forest', 'evaluator']}
# {'pipeline_id': '73ac8d3bdcf84984a2452f86fbe9d7db', 'output': np.float64(0.9666666666666667), 'runtime': 1.6978995999999995, 'tasks': ['data_loader', 'train_test_splitter', 'svc', 'evaluator']}
