# %%
import statfin
from matplotlib import pyplot as plt

# %%
StatFin = statfin.StatFin()

# %%
StatFin.StatFin.khi
# Out:
# statfin.PxWebAPI
#   url: https://statfin.stat.fi/PXWeb/api/v1/fi/StatFin/khi
#   title: Kuluttajahintaindeksi
#   index:
#     (t) statfin_khi_pxt_11xb.px 11xb -- Kuluttajahintaindeksi (2015=100), kuukausitiedot, 2015M01-2025M04
#     (t) statfin_khi_pxt_11xc.px 11xc -- Kuluttajahintaindeksi (2015=100), vuositiedot, 2015-2024
#     (t) statfin_khi_pxt_11xd.px 11xd -- Kuluttajahintaindeksi (2010=100), kuukausitiedot, 2010M01-2025M04
#     (t) statfin_khi_pxt_11xe.px 11xe -- Kuluttajahintaindeksi (2010=100), vuositiedot, 2010-2024
#     (t) statfin_khi_pxt_11xf.px 11xf -- Kuluttajahintaindeksi (2005=100), kuukausitiedot, 2005M01-2025M04
#     (t) statfin_khi_pxt_11xg.px 11xg -- Kuluttajahintaindeksi (2005=100), vuositiedot, 2005-2024
#     (t) statfin_khi_pxt_11xh.px 11xh -- Yhdenmukaistettu kuluttajahintaindeksi (YKHI) ja Yhdenmukaistettu kuluttajahintaindeksi kiintein veroin (YKHI-KIVE) (2015=100), kuukausitiedot, 2015M01-2025M04
#      ... and 21 more

# %%
StatFin.khi._11xt.query(Indeksisarja="0_1972")()
# Out:
#         Vuosi Indeksisarja  Pisteluku
# 0  1972-01-01       0_1972      100.0
# 1  1973-01-01       0_1972      110.7
# 2  1974-01-01       0_1972      129.4
# 3  1975-01-01       0_1972      152.5
# 4  1976-01-01       0_1972      174.4
# 5  1977-01-01       0_1972      196.4
# 6  1978-01-01       0_1972      211.3
# 7  1979-01-01       0_1972      226.7
# 8  1980-01-01       0_1972      253.0
# 9  1981-01-01       0_1972      283.4
# 10 1982-01-01       0_1972      309.7
# 11 1983-01-01       0_1972      336.2
# 12 1984-01-01       0_1972      359.7
# 13 1985-01-01       0_1972      380.8
# 14 1986-01-01       0_1972      394.5
# 15 1987-01-01       0_1972      409.0
# 16 1988-01-01       0_1972      429.0
# 17 1989-01-01       0_1972      457.3
# 18 1990-01-01       0_1972      485.1
# 19 1991-01-01       0_1972      505.2
# 20 1992-01-01       0_1972      518.3
# 21 1993-01-01       0_1972      529.2
# 22 1994-01-01       0_1972      535.0
# 23 1995-01-01       0_1972      540.2
# ...

# %%
Vero = statfin.Vero()

# %%
Vero.Vero.Henkiloasiakkaiden_tuloverot.lopulliset.tulot
# Out:
# statfin.PxWebAPI
#   url: https://vero2.stat.fi/PXWeb/api/v1/fi/Vero/Henkiloasiakkaiden_tuloverot/lopulliset/tulot
#   title: 01. Tulot
#   index:
#     (t) tulot_101.px 1.1 Tulot tulonsaajaryhmittäin ja tuloluokittain
#     (t) tulot_103.px 1.2 Tulot tulonsaajaryhmittäin ja ikäluokittain
#     (t) tulot_104.px 1.3 Tulot tulonsaajaryhmittäin ja sukupuolittain

# %%
StatFin.ntp._11tj.query()._fetch_json()
# Out:
# {'columns': [{'code': 'Vuosineljännes', 'text': 'Vuosineljännes', 'type': 't'},
#   {'code': 'Taloustoimi', 'text': 'Taloustoimi', 'type': 'd'},
#   {'code': 'Toimiala', 'text': 'Toimiala', 'type': 'd'},
#   {'code': 'KAUSIT',
#    'text': 'Kausitasoitettu ja työpäiväkorjattu sarja',
#    'type': 'c'},
#   {'code': 'TASM', 'text': 'Alkuperäinen sarja', 'type': 'c'},
#   {'code': 'TRENDI', 'text': 'Trendisarja', 'type': 'c'},
#   {'code': 'TYOP', 'text': 'Työpäiväkorjattu sarja', 'type': 'c'}],
#  'comments': [],
#  'data': [{'key': ['1990Q1', 'E1', 'SSS'],
#    'values': ['2492.4', '2426.4', '2494.0', '2426.4']},
#   {'key': ['1990Q1', 'E1', '0XS13'],
#    'values': ['1909.3', '1848.0', '1910.6', '1848.0']},
#   {'key': ['1990Q1', 'E1', '0S13'],
#    'values': ['583.1', '578.4', '583.4', '578.4']},
#   {'key': ['1990Q1', 'E1', 'A'],
#    'values': ['206.7', '198.4', '205.5', '198.4']},
#   {'key': ['1990Q1', 'E1', 'BTE'],
#    'values': ['523.1', '504.8', '524.5', '504.8']},
# ...
