# %% [markdown]
# # Test of EC Data
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
from ec4py import EC_Data
#from ec4py import *
from ec4py import Quantity_Value_Unit as QV
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 from ec4py import EC_Data
#       3 #from ec4py import *
#       4 from ec4py import Quantity_Value_Unit as QV
#
# File c:\Users\gusta\Documents\GitHub\EC4py\src\ec4py\__init__.py:17
#      11 from .cv_datas import CV_Datas
#      12 #from ec4py.step_data import Step_Data
#      13
#      14 #from typing import TYPE_CHECKING
#      15 #if TYPE_CHECKING:  # Only imports the below statements during type checking
# ---> 17 from .step_data import Step_Data
#      18 #import ec4py.step_data as step_data
#      19 #if TYPE_CHECKING:  # Only imports the below statements during type checking
#      20 from .step_datas import Step_Datas
#
# File c:\Users\gusta\Documents\GitHub\EC4py\src\ec4py\step_data.py:13
#      10 import copy
#      12 from .ec_data import EC_Data,index_at_time
# ---> 13 from .ec_util import EC_Channels
#      14 from .util_data import get_IR
#      17 from .ec_setup import EC_Setup
#
# ImportError: cannot import name 'EC_Channels' from 'ec4py.ec_util' (c:\Users\gusta\Documents\GitHub\EC4py\src\ec4py\ec_util\__init__.py)

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"CV"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
file = ( path_to_dataSetFolder / "CV_153559_ 3.tdms")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\CV

# %% [markdown]
# ## 3. Load in the data files

# %%
data = EC_Data(file)

# %%
print(data.channels)
b = data.get_channel("i")
print(b)
a,b,c,d =data.get_channel("Z_E1")
print(b,c,"DDD",d)
print(data.rawdata['Time'].properties)
data.rawdata['E'].properties.get("wf_increment",1)
# Out:
# ['Time', 'E', 'i', 'Z_E', 'Phase_E']
# (array([-0.00115615, -0.00114274, -0.00113355, ..., -0.00116737,
#        -0.00117945, -0.00116157], dtype=float32), 'i', 'A', 0.003999599999999997)
# Z_E Ohm DDD 0.003999599999999997
# OrderedDict([('unit_string', 's'), ('Quantity', 'Time'), ('wf_start_time', np.datetime64('2024-06-19T13:35:59.571391')), ('wf_start_offset', 0.0), ('wf_increment', 0.003999599999999997), ('wf_samples', 25), ('NI_ChannelName', 'Time'), ('NI_UnitDescription', 's')])
# 0.003999599999999997

# %%
#plot = CVs.plot("" ,legend = "name", smooth_y=50)

data.plot("E","i")
data.plot("i","E",AREA, title = "E vs i")
print(data.setup_data.dateTime)
data.area
# Out:
# 2024-06-19T13:35:59.839158
# A = 1.960e-05 m^2

# %%
print(data.setup)
print(data.channels)
# Out:
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.500 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '13.2', 'Method.Cycle Duration': '4.4', 'Method.Avg.Time': '0.004', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '1600.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# ['Time', 'E', 'i', 'Z_E', 'Phase_E']
