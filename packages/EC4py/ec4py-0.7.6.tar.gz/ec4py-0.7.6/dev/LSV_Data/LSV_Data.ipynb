# %% [markdown]
# # Levich and Koutechy-Levich analysis notebook for CV data.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
import numpy as np
from ec4py import *
from ec4py import Quantity_Value_Unit as QV

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"CV"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\CV

# %% [markdown]
# ## 3. Load in the data files

# %%
data = LSV_Data(paths[0])
# Out:
# zero_crossings [549]

# %%
data.norm(AREA)
data.plot()
# Out:
# (<matplotlib.lines.Line2D at 0x1fa47602d10>,
#  <Axes: xlabel='E vs RHE (V)', ylabel='i A$^{-1}$ (A m$^{-2}$)'>)

# %%
data2 = LSV_Data()
data2.copy_from(data)
data2.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 data2 = LSV_Data()
#       2 data2.copy_from(data)
# ----> 3 data2.plot()
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\lsv_data.py:327, in LSV_Data.plot(self, *args, **kwargs)
#     323 options.legend = self.legend(*args, **kwargs)
#     324 #if options.legend == "_" :
#     325 #        data_plot_kwargs["legend"] = data.setup_data.name
#     326 #data
# --> 327 data.norm(args)
#     328 data.set_active_RE(args)
#     329 options.x_data = data.E
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\lsv_data.py:275, in LSV_Data.norm(self, norm_to)
#     268 def norm(self, norm_to:str| tuple):
#     269     """Normalize lsv current
#     270
#     271     Args:
#     272         norm_to (str): _description_
#     273     """
# --> 275     r,qv = Voltammetry.norm(self, norm_to,[self.i ] )
#     276     #print("CCCC",r)
#     277     #print("CCCC",qv)
#     278             #n = Voltammetry.norm(self, norm_to,self.i_n )
#     280     if r is not None:
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\util_voltammetry.py:326, in Voltammetry.norm(self, norm_to, current)
#     322     i_shifted = current.copy()
#     323     for i in range(len(current)):
#     324         # print("aaaa-shifting",i)
# --> 326         i_shifted[i] = current[i] / float(norm_factor)
#     327 else:
#     328     i_shifted = current / float(norm_factor)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'float'

# %%
data = LSV_Data()
print(len(data.E))
data.i = np.ones(len(data.E))
q = data.integrate(0,1)
# Out:
# 5001
