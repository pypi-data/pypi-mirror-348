# %%
pip install pytest
# Out:
# Requirement already satisfied: pytest in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (8.3.5)
# Requirement already satisfied: colorama in c:\users\gusta\appdata\roaming\python\python313\site-packages (from pytest) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (from pytest) (2.1.0)
# Requirement already satisfied: packaging in c:\users\gusta\appdata\roaming\python\python313\site-packages (from pytest) (24.1)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\gusta\appdata\local\programs\python\python313\lib\site-packages (from pytest) (1.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
from ec4py import *
from ec4py import Quantity_Value_Unit as QV
from ec4py.analysis_tafel import Tafel
import numpy as np
import matplotlib.pyplot as plt
import math
import pytest

# %%
E =np.array([1,2,3,4,5,6,7])

y_data = (10**E) #np.power(10,E)
unit = "AAA"
result = Tafel(E, y_data, unit, "", "b")
print(result)
y_data = 10**(0.1*E)
result2 =  Tafel(E, y_data, unit, "", "b")
print(result2)
# Out:
# 1.000e+00 V/dec
# 1.000e+01 V/dec
