# %% [markdown]
# # Tafel.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
import numpy as np
from ec4py.analysis_tafel import Tafel
from ec4py.util_graph import make_plot_1x
from ec4py import Quantity_Value_Unit as QV

import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.Basic properties of a Tafel

# %%
E =np.array([3,4,5,6,7,8])
y_data = 10**(E/0.120)
unit = "AAA"
result = Tafel(E, y_data, "AAA", "BBB", "b", x_label = "ABE")
print(result.value)
# Out:
# 0.12000000000000009

# %%
p = make_plot_1x("Title")
Tafel(E, y_data, "AAA", "BBB", "b",plot=p)
print(str(p.get_ylabel()))
str(p.get_ylabel)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 p = make_plot_1x("Title")
# ----> 2 Tafel(E, y_data, "AAA", "BBB", "b",plot=p)
#       3 print(str(p.get_ylabel()))
#       4 str(p.get_ylabel)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\analysis_tafel.py:37, in Tafel(x_data, y_data, y_axis_unit, y_axis_title, plot_color, lineName, x_data_ext, y_data_ext, **kwargs)
#      35 p.x_label = kwargs.get("x_label","E")
#      36 p.x_unit = kwargs.get("x_unit","V")
# ---> 37 line, analyse_plot = p.exe()
#      38 if x_data_ext is not None and y_data_ext is not None:
#      39     y_data_ext = np.log10(np.abs(y_data_ext))
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\util_graph.py:241, in plot_options.exe(self)
#     239 except:  # noqa: E722
#     240     pass
# ...
