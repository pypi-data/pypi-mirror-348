# %% [markdown]
# # Test of EC Data
#
# ## 1. Import needed libraries

# %%
from ec4py import Quantity_Value_Unit as QV

from pathlib import Path
from ec4py import EC_Data
from ec4py.eis_data import EIS_Data


import numpy as np

import matplotlib.pyplot as plt

# %%
from ec4py.util_eis import make_Bode_plot
make_Bode_plot()
# Out:
# (<Axes: xlabel='Freq (Hz)', ylabel='Z (Ohm)'>,
#  <Axes: xlabel='Freq (Hz)', ylabel='Phase (rad)'>,
#  <ec4py.util_graph.plot_options at 0x1665b915820>,
#  <ec4py.util_graph.plot_options at 0x1665b9663f0>)

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"EIS"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
file = ( path_to_dataSetFolder / "EIS_140804.tdms")
# Out:
# c:\Users\gusta\Documents\GitHub\NordicEC\EC4py\test_data\EIS

# %% [markdown]
# ## 3. Load in the data files

# %%
data = EIS_Data(file,"Cell")

# %%
#plot = CVs.plot("" ,legend = "name", smooth_y=50)

a,b =data.nq("area",maxf=20000,minf=10)
#print(b.get_xlim())
#b.set_xlim(0,None)
print(a.get_label())
# Out:
# _

# %%
a,b = data.bode(left=0.1,maxf=10000)
