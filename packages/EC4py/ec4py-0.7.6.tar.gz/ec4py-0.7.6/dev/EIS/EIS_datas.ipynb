# %% [markdown]
# # Test of EIS Datas
#
# ## 1. Import needed libraries

# %%
from ec4py import Quantity_Value_Unit as QV

from pathlib import Path
from ec4py import EC_Data
from ec4py.eis_datas import EIS_Datas


import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"EIS"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
file = ( path_to_dataSetFolder / "EIS_140804.tdms")
# Out:
# c:\Users\gusta\Documents\GitHub\NordicEC\EC4py\test_data\EIS

# %% [markdown]
# ## 3. Load in the data files

# %%
data = EIS_Datas(file,"Cell")

# %%
data.bode("area",maxf=10000,right=10000,legend="name")

# %%
#plot = CVs.plot("" ,legend = "name", smooth_y=50)

a,b = data.nq("AREA", maxf=1000,legend="name")
print(a.lines)
print(len(a.lines))
#print(b.get_xlim())
#b.set_xlim(0,None)
a.get_legend
# Out:
# <Axes.ArtistList of 2 lines>
# 2
# <bound method _AxesBase.get_legend of <Axes: xlabel='Z_re A$^{-1}$ (Ohm m$^{-2}$)', ylabel='-Z_im A$^{-1}$ (Ohm m$^{-2}$)'>>

# %%
a,b = data.bode(left=0.1,maxf=10000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a,b = data.bode(left=0.1,maxf=10000)
#
# TypeError: cannot unpack non-iterable NoneType object
