# %%
from ec4py import CV_Data,CV_Datas

# %%
fileList= [
               "C:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\EC4py\\test_data\\CV\\CV_144700_ 3.tdms",
               "C:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\EC4py\\test_data\\CV\\CV_144913_ 3.tdms"
   ]


datas = CV_Datas(fileList)
# Out:
# TDMS file was not found: C:\Users\gustav.wiberg\Documents\GitHub\Python\EC4py\test_data\CV\CV_144700_ 3.tdms
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 fileList= [
#       2                "C:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\EC4py\\test_data\\CV\\CV_144700_ 3.tdms",
#       3                "C:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\EC4py\\test_data\\CV\\CV_144913_ 3.tdms"
#       4    ]
# ----> 7 datas = CV_Datas(fileList)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_datas.py:59, in CV_Datas.__init__(self, paths, *args, **kwargs)
#      57 ec = EC_Data(path)
#      58 try:
# ---> 59     self.datas[index].conv(ec,*args,**kwargs)
#      60 finally:
#      61     index=index+1
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_data.py:203, in CV_Data.conv(self, ec_data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

# %%
fileName ="cv_datas_ex1_"

# %%
datas.plot(legend="Rate", y_smooth=0)
plt.savefig(fileName +"fig1.png", dpi='figure', format=None)

# %%
p = datas.plot("area","rate", legend="Rate")
#datas.plot(dir="neg", plot = p)
plt.savefig(fileName +"fig2.png", dpi='figure', format=None)
