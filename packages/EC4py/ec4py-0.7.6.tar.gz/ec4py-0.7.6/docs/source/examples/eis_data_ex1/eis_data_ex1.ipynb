# %%
from ec4py import EIS_Data

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
load_dotenv()

projectPath = Path(os.getenv("PROJECT_FOLDER"))
print(projectPath)
# Out:
# C:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py

# %%
data = EIS_Data(projectPath /"test_data" / "CV" / "CV_144700_ 3.tdms")
# Out:
# Error:Frequency channel name is not supported
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\.venv\Lib\site-packages\nptdms\tdms.py:462, in TdmsGroup.__getitem__(self, channel_name)
#     461 try:
# --> 462     return self._channels[channel_name]
#     463 except KeyError:
#
# KeyError: 'Frequency'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\ec_data.py:161, in EC_Data.get_channel(self, datachannel)
#     160 try:
# --> 161     unit = self.rawdata[datachannel].properties.get("unit_string", "")
#     162     quantity = self.rawdata[datachannel].properties.get("Quantity", "")
#
# File c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\.venv\Lib\site-packages\nptdms\tdms.py:464, in TdmsGroup.__getitem__(self, channel_name)
#     463 except KeyError:
# --> 464     raise KeyError(
#     465         "There is no channel named '%s' in group '%s' of the TDMS file" %
#     466         (channel_name, self.name))
#
# KeyError: "There is no channel named 'Frequency' in group 'EC' of the TDMS file"
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\eis_data.py:56, in EIS_Data.conv(self, ec_data, *args, **kwargs)
#      55 self.setup_data = copy.deepcopy(ec_data.setup_data)
# ---> 56 data_f,q,u = ec_data.get_channel("Frequency")
#      57 data_E,q,u = ec_data.get_channel(sel_channels.Voltage)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\ec_data.py:165, in EC_Data.get_channel(self, datachannel)
#     164 except KeyError:
# --> 165     raise NameError("Error:" + datachannel + " channel name is not supported")
#
# NameError: Error:Frequency channel name is not supported
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = EIS_Data(projectPath /"test_data" / "CV" / "CV_144700_ 3.tdms")
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\eis_data.py:48, in EIS_Data.__init__(self, *args, **kwargs)
#      45     return
#      46 else:
#      47     #print(kwargs)
# ---> 48     self.conv(EC_Data(args[0]), *args, **kwargs)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\eis_data.py:66, in EIS_Data.conv(self, ec_data, *args, **kwargs)
#      64 except NameError as e:
#      65     print(e)
# ---> 66     raise NameError(e)
#      67     return
#      69 return
#
# NameError: Error:Frequency channel name is not supported

# %%
import matplotlib.pyplot as plt

# %%
data.plot()
plt.savefig("cv_data_ex1_fig1.png", dpi='figure', format=None)

# %%
line, p = data.plot(dir="pos")
data.plot(dir="neg", plot = p)
plt.savefig("cv_data_ex1_fig2.png", dpi='figure', format=None)

# %%
i_p, i_n = data.get_i_at_E(-0.4)
print(i_p,i_n)
# Out:
# -8.721552504123802e-07 -7.099501801377031e-06
